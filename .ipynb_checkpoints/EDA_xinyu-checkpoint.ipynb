# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
df_consumer = pd.read_excel('./data/U of M Student Data - Consumer Discretionary .xlsx', 
                           skiprows=7)

# %%
# overview of the data
df_consumer.head(3)
# Out:
#                               Company Name Exchange:Ticker  \
# 0  1-800-FLOWERS.COM, Inc. (NasdaqGS:FLWS)   NasdaqGS:FLWS
# 1         A.H. Belo Corporation (NYSE:AHC)        NYSE:AHC
# 2                 Aaron's, Inc. (NYSE:AAN)        NYSE:AAN
#
#            Industry Classifications    Company Type  \
# 0  Consumer Discretionary (Primary)  Public Company
# 1  Consumer Discretionary (Primary)  Public Company
# 2  Consumer Discretionary (Primary)  Public Company
#
#                  Geographic Locations  \
# 0  United States of America (Primary)
# 1  United States of America (Primary)
# 2  United States of America (Primary)
#
#   Total Enterprise Value [My Setting] [12/31/2016] ($USDmm, Historical rate)  \
# 0                                              927.6
# 1                                               61.9
# 2                                             2461.3
#
#    Total Revenue [LTM] ($USDmm, Historical rate)  \
# 0                                         1189.0
# 1                                          267.0
# 2                                         3234.0
#
#    EBITDA [LTM] ($USDmm, Historical rate)  EBITDA Margin % [LTM]  \
# 0                                   78.90                   6.64
# 1                                    5.92                   2.22
# 2                                  462.80                  14.30
#
#    TEV/LTM Total Revenues [My Setting] [LTM as of 12/31/2016] (x)  \
# 0                                              0.784
# 1                                              0.232
# 2                                              0.761
#
#                   ...                  Total Revenues, 3 Yr CAGR % [LTM] (%)  \
# 0                 ...                                                   16.4
# 1                 ...                                                  -4.04
# 2                 ...                                                     13
#
#   EBITDA, 3 Yr CAGR % [LTM] (%) Total Revenues, 5 Yr CAGR % [LTM] (%)  \
# 0                          19.4                                  11.2
# 1                         -34.5                                 -10.6
# 2                           9.6                                  10.3
#
#   EBITDA, 5 Yr CAGR % [LTM] (%) Return on Assets % [LTM]  \
# 0                          18.7                      4.6
# 1                         -28.9                    -1.57
# 2                          11.2                     9.93
#
#   Return on Equity % [LTM] Capex as % of Revenues [Latest Annual] (%)  \
# 0                      9.9                                       2.89
# 1                    -12.2                                       2.78
# 2                     9.95                                        1.9
#
#   EBITDA / Interest Exp. [LTM] Total Debt/Capital % [Latest Annual]  \
# 0                         12.7                                 32.6
# 1                            -                                    -
# 2                         19.1                                 30.9
#
#   Total Debt/Equity % [Latest Annual]
# 0                                48.5
# 1                                   -
# 2                                44.7
#
# [3 rows x 25 columns]

# %%
df_consumer.replace('-', np.NaN, inplace=True)
df_consumer.replace('NM', np.NaN, inplace=True)
print 'excel sheet shape: ', df_consumer.shape
print 'columns name: ', df_consumer.columns.tolist()
# Out:
# excel sheet shape:  (513, 25)
# columns name:  [u'Company Name', u'Exchange:Ticker', u'Industry Classifications', u'Company Type', u'Geographic Locations', u'Total Enterprise Value [My Setting] [12/31/2016] ($USDmm, Historical rate)', u'Total Revenue [LTM] ($USDmm, Historical rate)', u'EBITDA [LTM] ($USDmm, Historical rate)', u'EBITDA Margin % [LTM]', u'TEV/LTM Total Revenues [My Setting] [LTM as of 12/31/2016] (x)', u'TEV/LTM EBITDA [My Setting] [LTM as of 12/31/2016] (x)', u'Est. Annual Revenue Growth - 1 Yr % - Capital IQ [Latest] (%)', u'Est. Annual EBITDA Growth - 1 Yr % - Capital IQ [Latest] (%)', u'Total Revenues, 1 Yr Growth % [LTM] (%)', u'EBITDA, 1 Yr Growth % [LTM] (%)', u'Total Revenues, 3 Yr CAGR % [LTM] (%)', u'EBITDA, 3 Yr CAGR % [LTM] (%)', u'Total Revenues, 5 Yr CAGR % [LTM] (%)', u'EBITDA, 5 Yr CAGR % [LTM] (%)', u'Return on Assets % [LTM]', u'Return on Equity % [LTM]', u'Capex as % of Revenues [Latest Annual] (%)', u'EBITDA / Interest Exp. [LTM]', u'Total Debt/Capital % [Latest Annual]', u'Total Debt/Equity % [Latest Annual]']

# %%
# brief overview of each column's information
i = 0
for col in df_consumer.columns:
    print 'feature name: ', col
    print 'data type: ', df_consumer[col].dtype
    print 'proportional of NA value', np.sum(df_consumer[col].isnull())/float(df_consumer.shape[0])
    if df_consumer[col].dtype != 'object':
        i += 1
    print 
print 'number of numeric columns', i
# Out:
# feature name:  Company Name
# data type:  object
# proportional of NA value 0.0
#
# feature name:  Exchange:Ticker
# data type:  object
# proportional of NA value 0.0
#
# feature name:  Industry Classifications
# data type:  object
# proportional of NA value 0.0
#
# feature name:  Company Type
# data type:  object
# proportional of NA value 0.0
#
# feature name:  Geographic Locations
# data type:  object
# proportional of NA value 0.0
#
# feature name:  Total Enterprise Value [My Setting] [12/31/2016] ($USDmm, Historical rate)
# data type:  float64
# proportional of NA value 0.0272904483431
#
# feature name:  Total Revenue [LTM] ($USDmm, Historical rate)
# data type:  float64
# proportional of NA value 0.0
#
# feature name:  EBITDA [LTM] ($USDmm, Historical rate)
# data type:  float64
# proportional of NA value 0.0
#
# feature name:  EBITDA Margin % [LTM]
# data type:  float64
# proportional of NA value 0.0
#
# feature name:  TEV/LTM Total Revenues [My Setting] [LTM as of 12/31/2016] (x)
# data type:  float64
# proportional of NA value 0.0
#
# feature name:  TEV/LTM EBITDA [My Setting] [LTM as of 12/31/2016] (x)
# data type:  float64
# proportional of NA value 0.0
#
# feature name:  Est. Annual Revenue Growth - 1 Yr % - Capital IQ [Latest] (%)
# data type:  float64
# proportional of NA value 0.206627680312
#
# feature name:  Est. Annual EBITDA Growth - 1 Yr % - Capital IQ [Latest] (%)
# data type:  float64
# proportional of NA value 0.249512670565
#
# feature name:  Total Revenues, 1 Yr Growth % [LTM] (%)
# data type:  float64
# proportional of NA value 0.0136452241715
#
# feature name:  EBITDA, 1 Yr Growth % [LTM] (%)
# data type:  float64
# proportional of NA value 0.0506822612086
#
# feature name:  Total Revenues, 3 Yr CAGR % [LTM] (%)
# data type:  float64
# proportional of NA value 0.0994152046784
#
# feature name:  EBITDA, 3 Yr CAGR % [LTM] (%)
# data type:  float64
# proportional of NA value 0.138401559454
#
# feature name:  Total Revenues, 5 Yr CAGR % [LTM] (%)
# data type:  float64
# proportional of NA value 0.194931773879
#
# feature name:  EBITDA, 5 Yr CAGR % [LTM] (%)
# data type:  float64
# proportional of NA value 0.235867446394
#
# feature name:  Return on Assets % [LTM]
# data type:  float64
# proportional of NA value 0.0214424951267
#
# feature name:  Return on Equity % [LTM]
# data type:  float64
# proportional of NA value 0.111111111111
#
# feature name:  Capex as % of Revenues [Latest Annual] (%)
# data type:  float64
# proportional of NA value 0.0272904483431
#
# feature name:  EBITDA / Interest Exp. [LTM]
# data type:  float64
# proportional of NA value 0.130604288499
#
# feature name:  Total Debt/Capital % [Latest Annual]
# data type:  float64
# proportional of NA value 0.132553606238
#
# feature name:  Total Debt/Equity % [Latest Annual]
# data type:  float64
# proportional of NA value 0.233918128655
#
# number of numeric columns 20

# %%
# plot the relationship between 
# 'Total Enterprise Value [My Setting] [12/31/2016] ($USDmm, Historical rate)' and other
# numerical features
import textwrap
target_col = 'Total Enterprise Value [My Setting] [12/31/2016] ($USDmm, Historical rate)'
index = ~df_consumer[target_col].isnull()
fig, ax = plt.subplots(10,2, sharex=True, figsize=(20, 80))
a = ax.flatten()
i = 0
for col in df_consumer.columns:
    if df_consumer[col].dtype != 'object' and col != target_col:
        a[i].plot(df_consumer[target_col], df_consumer[col], 'o', alpha=0.5)
        a[i].set_ylabel('\n'.join(textwrap.wrap(col, 20)), fontsize=18)
        i += 1
plt.xlabel(target_col, fontsize=18, ha='center')
fig.savefig('consumer_scatter_plot.png')
