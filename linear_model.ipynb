# %% [markdown]
# # Basic Linear Model

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model

# %%
# Generate 2-D Correlated Dataset (100 samples, 2 dimensions)
data = datasets.make_low_rank_matrix(100, 2, effective_rank=0.05, tail_strength=0.5)
plt.plot(data[:,0], data[:,1], '.b')
plt.show()

# %%
consumer = pd.read_excel('./data/U of M Student Data - Consumer Discretionary .xlsx', 'Screening', index_col=None, skiprows=7,  na_values=['NA'])
type(consumer)
# Out:
# pandas.core.frame.DataFrame

# %%
type()
